# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
X = cv2.imread('../TIA/imagenes/3.jpeg',0)
plt.imshow(X,cmap='gray')
plt.title('original')
plt.show()

# %%
n = 60

Xe = cv2.morphologyEx(X, cv2.MORPH_OPEN, cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (n,n)))



plt.figure(figsize=(10,10))
plt.imshow(Xe,cmap='gray')
plt.title('open')
plt.show()

# %%
Xd = X.astype(float) -Xe.astype(float)
plt.figure(figsize=(10,10))
plt.imshow(Xd,cmap='gray')
plt.title('difference')
plt.show()

# %%
th = 80
D = Xd>th
plt.figure(figsize=(10,10))
plt.imshow(D,cmap='gray')
plt.title('detection')
plt.show()

# %%
from skimage.morphology import binary_dilation
from skimage.segmentation import clear_border


from skimage.color import label2rgb
from skimage.measure import label

# %%
hist = cv2.calcHist([X],[0],None,[256],[0,256])
print(hist.shape)
# Out:
# (256, 1)

# %%
plt.plot(hist), plt.title("Histograma")
# Out:
# ([<matplotlib.lines.Line2D at 0x1e221d82670>], Text(0.5, 1.0, 'Histograma'))

# %%
#img = cv2.medianBlur(Xd,5)
th2 = cv2.adaptiveThreshold(Xd,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,\
            cv2.THRESH_BINARY,11,2)

plt.figure(figsize=(10,10))
plt.imshow(th2,cmap='gray')
plt.title('detection')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# C:\Users\BRAYAN~1\AppData\Local\Temp/ipykernel_11344/2632784445.py in <module>
#       1 #img = cv2.medianBlur(Xd,5)
# ----> 2 th2 = cv2.adaptiveThreshold(Xd,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,\
#       3             cv2.THRESH_BINARY,11,2)
#       4
#       5 plt.figure(figsize=(10,10))
#
# error: OpenCV(4.5.3) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-u4kjpz2z\opencv\modules\imgproc\src\thresh.cpp:1676: error: (-215:Assertion failed) src.type() == CV_8UC1 in function 'cv::adaptiveThreshold'

# %%
# Out:
# numpy.ndarray

# %%
ret,thresh1 = cv2.threshold(Xd,50,255,cv2.THRESH_BINARY)
plt.figure(figsize=(10,10))
plt.imshow(thresh1,cmap='gray')
plt.title('detection')
plt.show()
